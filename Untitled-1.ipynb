# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# d:\Project\final-yr-model

# %%
# %pip install ultralytics
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")  # or yolov8s.pt for better accuracy

model.train(
    data=r"D:\Project\final-yr-model\data.yaml",
    epochs=5,
    imgsz=224
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.130 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.129  Python-3.12.10 torch-2.7.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...

# %%
Image(filename=f'C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/confusion_matrix.png',width = 600)

# %%
Image(filename=f"C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/confusion_matrix_normalized.png",width = 600)

# %%
from IPython.display import Image, display

# Display F1 Curve image for performance visualization
display(Image(filename="C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/F1_curve.png", width=600))

# %%
Image(filename=f"C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/P_curve.png",width = 600)

# %%
Image(filename=f"C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/PR_curve.png",width = 600)

# %%
Image(filename=f"C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/results.png",width = 600)

# %%
import glob
from IPython.display import Image, display

# Define the path pattern for image detection outputs
image_paths = glob.glob("C:/Users/Ravi Ranjan/model/Emergency-Detection-And-Alert-System/runs/detect/train4/*.jpg")

# Display up to three detected images for visual verification
for image_path in image_paths[:3]:
    display(Image(filename=image_path, width=600, height=600))

# %%
# Ensure required packages are installed
# %pip install opencv-python
# %pip install ultralytics

# Import necessary libraries
from ultralytics import YOLO
import cv2

# Load YOLOv8 model (nano version)
model = YOLO("yolov8n.pt")

# Run real-time prediction using the webcam (source=0)
# show=True enables live annotated display
results = model.predict(source=0, show=True)

# Print summary of detection results
print("Detection Results Summary:")
for result in results:
    print(result)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 142.0ms
# 0: 480x640 1 person, 130.4ms
# 0: 480x640 1 person, 195.3ms
# 0: 480x640 1 person, 116.2ms
# 0: 480x640 1 person, 122.0ms
# 0: 480x640 1 person, 170.9ms
# 0: 480x640 1 person, 156.4ms
# ...
